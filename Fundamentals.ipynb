# %% [markdown]
# # Python Programming Fundamentals
#
# You can run this from binder, using: https://mybinder.org/v2/gh/rodsenra/python_course/master
#
# The material is split into 4 parts:
# * Part 1 - Fundamentals: Primitive Types
# * Part 2 - Namespaces: Functions, Classes, Modules and Packages
# * Part 3 - Object Orientation
# * Part 4 - Functional Programming
#
# On this (2hs) Webinar we will focus on **Part 1: Fundamentals: Primitive Types**.
#
# We will mention aspects of OO and Functional programming as well.
#
# All examples in **Python 3**!

# %% [markdown]
# # Executing Python Code
#
#  * Interactive Mode ```python```
#  * Run script or program ```python blah.py```
#  * Run script and fallback to interactive mode ```python -i bla.py```
#  * Single command line expression ```python -c 'print(3*15)'```

# %% [markdown]
# # Using Jupyter

# %% [markdown]
# We start by exploring Python scalar native types at the REPL.
# We will use some builtin functions to explain the connection between scalar types and Python's Object Oriented nature.

# %% [markdown]
# # Fundamentals
#
# In this first part, we will visit first the primitive types in Python, and then explore the statements that allow us to manipulate those types to build programs.
# We are going to use the REPL (Read-Eval-Print-Loop) as the main tool to explore the language.
#
# ## Numbers and using Python as a calculator

# %%
1
# Out:
# 1

# %%
1.0
# Out:
# 1.0

# %%
1 == 1.0
# Out:
# True

# %%
1 is 1.0
# Out:
# False

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
isinstance(1, int)
# Out:
# True

# %% [markdown]
# We even have complex numbers as native scalar types!

# %%
1 + 0j
# Out:
# (1+0j)

# %%
type(1 + 0j)
# Out:
# complex

# %%
(1 + 0j) + (3 - 5j)
# Out:
# (4-5j)

# %%
3 / 2
# Out:
# 1.5

# %%
3 // 2
# Out:
# 1

# %%
1 / 0
# Out:
# ------------------------------------------------------------
# ZeroDivisionError          Traceback (most recent call last)
# <ipython-input-23-bc757c3fda29> in <module>()
# ----> 1 1 / 0
#
# ZeroDivisionError: division by zero

# %%
2*2*2
# Out:
# 8

# %%
2**3
# Out:
# 8

# %%
2**1024
# Out:
# 

# %%
2**4096 + 1
# Out:
# ...

# %%
_
# Out:
# ...

# %%
_ + 1
# Out:
# ...

# %%
2**4096 / 2
# Out:
# ------------------------------------------------------------
# OverflowError              Traceback (most recent call last)
# <ipython-input-31-2b757219159a> in <module>()
# ----> 1 2**4096 / 2
#
# OverflowError: integer division result too large for a float

# %% [markdown]
# Advanced topic, for those who want to go further after the webinar ...

# %%
from decimal import Decimal
Decimal(2**4096) / 2
# Out:
# Decimal('5.221944407065762533458763554E+1232')

# %% [markdown]
# ## The Assignment Statement
# We use the assignment statement to bind names to values

# %%
x = 12

# %%
x
# Out:
# 12

# %%
y = x

# %%
x is y
# Out:
# True

# %%
type(x)
# Out:
# int

# %%
x**2
# Out:
# 144

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   'get_ipython().run_cell_magic(\'javascript\', \'\', \'console.log(1=="1")\\nconsole.log(1+"1")\\nconsole.log(2*"2")\')',
#   'get_ipython().run_cell_magic(\'javascript\', \'\', \'console.log(1=="1")\\nconsole.log(1+"1")\\nconsole.log(2*"2")\')',
#   '1',
#   '1',
#   '1',
#   '1.0',
#   '1 == 1.0',
#   '1 is 1.0',
#   'type(1)',
#   'type(1.0)',
#   'isinstance(1, object)',
#   'isinstance(1, float)',
#   'isinstance(1, int)',
#   '1 + 0j',
#   'type(1 + 0j)',
#   'type(1 + 0j)',
#   '1 + 0j == 1',
#   '(1 + 0j) * (3 - 5j)',
#   '(1 + 0j) + (3 - 5j)',
#   '3 / 2',
#   '3 // 2',
#   '3 // 2',
#   '1 / 0',
#   '2*2*2',
#   '2**3',
#   '2**1024',
#   '2**4096',
#   '2**4096 + 1',
#   '_',
#   '_ + 1',
#   '2**4096 / 2',
#   'from decimal import Decimal\nDecimal(2**4096) / 2',
#   'x = 12',
#   'x',
#   'y = x',
#   'x is y',
#   'type(x)',
#   'x**2',
#   'locals()'],
#  '_oh': {3: 1,
#   4: 1,
#   5: 1,
#   6: 1.0,
#   7: True,
#   8: False,
#   9: int,
#   10: float,
#   11: True,
#   12: False,
#   13: True,
#   14: (1+0j),
#   15: complex,
#   16: complex,
#   17: True,
#   18: (3-5j),
#   19: (4-5j),
#   20: 1.5,
#   21: 1,
#   22: 1,
#   24: 8,
#   25: 8,
#   26: ,
#   27: ...,
#   28: ...,
#   29: ...,
#   30: ...,
#   32: Decimal('5.221944407065762533458763554E+1232'),
#   34: 12,
#   36: True,
#   37: int,
#   38: 144},
#  '_dh': ['/Users/rodsenra/r/projects/python_course'],
#  'In': ['',
#   'get_ipython().run_cell_magic(\'javascript\', \'\', \'console.log(1=="1")\\nconsole.log(1+"1")\\nconsole.log(2*"2")\')',
#   'get_ipython().run_cell_magic(\'javascript\', \'\', \'console.log(1=="1")\\nconsole.log(1+"1")\\nconsole.log(2*"2")\')',
#   '1',
#   '1',
#   '1',
#   '1.0',
#   '1 == 1.0',
#   '1 is 1.0',
#   'type(1)',
#   'type(1.0)',
#   'isinstance(1, object)',
#   'isinstance(1, float)',
#   'isinstance(1, int)',
#   '1 + 0j',
#   'type(1 + 0j)',
#   'type(1 + 0j)',
#   '1 + 0j == 1',
#   '(1 + 0j) * (3 - 5j)',
#   '(1 + 0j) + (3 - 5j)',
#   '3 / 2',
#   '3 // 2',
#   '3 // 2',
#   '1 / 0',
#   '2*2*2',
#   '2**3',
#   '2**1024',
#   '2**4096',
#   '2**4096 + 1',
#   '_',
#   '_ + 1',
#   '2**4096 / 2',
#   'from decimal import Decimal\nDecimal(2**4096) / 2',
#   'x = 12',
#   'x',
#   'y = x',
#   'x is y',
#   'type(x)',
#   'x**2',
#   'locals()'],
#  'Out': {3: 1,
#   4: 1,
#   5: 1,
#   6: 1.0,
#   7: True,
#   8: False,
#   9: int,
#   10: float,
#   11: True,
#   12: False,
#   13: True,
#   14: (1+0j),
#   15: complex,
#   16: complex,
#   17: True,
#   18: (3-5j),
#   19: (4-5j),
#   20: 1.5,
#   21: 1,
#   22: 1,
#   24: 8,
#   25: 8,
#   26: ,
#   27: ...,
#   28: ...,
#   29: ...,
#   30: ...,
#   32: Decimal('5.221944407065762533458763554E+1232'),
#   34: 12,
#   36: True,
#   37: int,
#   38: 144},
#  'get_ipython': <bound method InteractiveShell.get_ipython of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x102c264a8>>,
#  'exit': <IPython.core.autocall.ZMQExitAutocall at 0x102c89518>,
#  'quit': <IPython.core.autocall.ZMQExitAutocall at 0x102c89518>,
#  '_': 144,
#  '__': int,
#  '___': True,
#  '_i': 'x**2',
#  '_ii': 'type(x)',
#  '_iii': 'x is y',
#  '_i1': '%%javascript\nconsole.log(1=="1")\nconsole.log(1+"1")\nconsole.log(2*"2")',
#  '_i2': '%%javascript\nconsole.log(1=="1")\nconsole.log(1+"1")\nconsole.log(2*"2")',
#  '_i3': '1',
#  '_3': 1,
#  '_i4': '1',
#  '_4': 1,
#  '_i5': '1',
#  '_5': 1,
#  '_i6': '1.0',
#  '_6': 1.0,
#  '_i7': '1 == 1.0',
#  '_7': True,
#  '_i8': '1 is 1.0',
#  '_8': False,
#  '_i9': 'type(1)',
#  '_9': int,
#  '_i10': 'type(1.0)',
#  '_10': float,
#  '_i11': 'isinstance(1, object)',
#  '_11': True,
#  '_i12': 'isinstance(1, float)',
#  '_12': False,
#  '_i13': 'isinstance(1, int)',
#  '_13': True,
#  '_i14': '1 + 0j',
#  '_14': (1+0j),
#  '_i15': 'type(1 + 0j)',
#  '_15': complex,
#  '_i16': 'type(1 + 0j)',
#  '_16': complex,
#  '_i17': '1 + 0j == 1',
#  '_17': True,
#  '_i18': '(1 + 0j) * (3 - 5j)',
#  '_18': (3-5j),
#  '_i19': '(1 + 0j) + (3 - 5j)',
#  '_19': (4-5j),
#  '_i20': '3 / 2',
#  '_20': 1.5,
#  '_i21': '3 // 2',
#  '_21': 1,
#  '_i22': '3 // 2',
#  '_22': 1,
#  '_i23': '1 / 0',
#  '_i24': '2*2*2',
#  '_24': 8,
#  '_i25': '2**3',
#  '_25': 8,
#  '_i26': '2**1024',
#  '_26': ,
#  '_i27': '2**4096',
#  '_27': ...,
#  '_i28': '2**4096 + 1',
#  '_28': ...,
#  '_i29': '_',
#  '_29': ...,
#  '_i30': '_ + 1',
#  '_30': ...,
#  '_i31': '2**4096 / 2',
#  '_i32': 'from decimal import Decimal\nDecimal(2**4096) / 2',
#  'Decimal': decimal.Decimal,
#  '_32': Decimal('5.221944407065762533458763554E+1232'),
#  '_i33': 'x = 12',
#  'x': 12,
#  '_i34': 'x',
#  '_34': 12,
#  '_i35': 'y = x',
#  'y': 12,
#  '_i36': 'x is y',
#  '_36': True,
#  '_i37': 'type(x)',
#  '_37': int,
#  '_i38': 'x**2',
#  '_38': 144,
#  '_i39': 'locals()'}

# %% [markdown]
# There is destructuring

# %%
x = a, b = 1, 2

# %%
a
# Out:
# 2

# %%
b
# Out:
# 1

# %%
x
# Out:
# (1, 2)

# %%
a, b = b, a

# %%
type(x)
# Out:
# tuple

# %%
c, d = x

# %%
y = b ,a

# %%
x=a,b = 1,2

# %%
id(a)
# Out:
# 4310495216

# %%
y=a,b=4,6

# %%
id(a)
# Out:
# 4310495312

# %%
id(x[0])
# Out:
# 4310495216

# %%
c == x[0]

# %%
del x

# %%
class M(object):
    def __init__(self, a, b):
        self.a = a
        self.b = b

# %%
m = M(1,2)

# %%
x = m.a, m.b

# %%
x
# Out:
# (1, 2)

# %% [markdown]
# ## Strings

# %%
'single quotes'
# Out:
# 'single quotes'

# %%
"double quotes"
# Out:
# 'double quotes'

# %%
'''triple
'single'
quotes
'''
# Out:
# "triple\n'single'\nquotes\n"

# %%
template = """
Name: Rod
Role: Bug Crusher
"""

# %%
print(template)
# Out:
# Name: Rod
# Role: Bug Crusher

# %%
type("some string")
# Out:
# str

# %%
"\n\t one two three \n\t".strip()
# Out:
# 'one two three'

# %%
def f(a, b):
    return a + b
    
f.__call__(1,2)
# Out:
# 3

# %%
f(1,2)
# Out:
# 3

# %% [markdown]
# ### Slice Operator

# %% [markdown]
# Understanding the slice operator indexing
# ```
#  +---+---+---+---+---+---+
#  | P | y | t | h | o | n |
#  +---+---+---+---+---+---+
#  0   1   2   3   4   5   6
# -6  -5  -4  -3  -2  -1
# ```
# From: https://docs.python.org/3/tutorial/introduction.html

# %%
x = "Python"

# %%
len(x)
# Out:
# 6

# %%
x[:]
# Out:
# 'Python'

# %% [markdown]
# a[start(including):end(Excluding) ] # from Kumar, thanks

# %%
x[:4], x[4:]
# Out:
# ('Pyth', 'on')

# %%
x[-1:-7:-1]
# Out:
# 'nohtyP'

# %%
"strings are sequence of chars indexed by 0"[0]
# Out:
# 's'

# %%
"the slice operator allows us to cut strings"[4:9]
# Out:
# 'slice'

# %%
"the index also comes from the end with negative values"[-1]
# Out:
# 's'

# %%
"you can cut just the value from the end"[-7:]
# Out:
# 'the end'

# %%
"y o u   c a n   s k i p"[::2]
# Out:
# 'you can skip'

# %%
"you can also reverse: 1 2 3"[-1:-6:-1]
# Out:
# '3 2 1'

# %%
"reverse all: 1 2 3"[::-1]
# Out:
# '3 2 1 :lla esrever'

# %%
"super_useful.txt"[:-4]
# Out:
# 'super_useful'

# %% [markdown]
# ### String Interpolation

# %%
x = "legacy"
"%s method" % x
# Out:
# 'legacy method'

# %%
x = "recent"
"{0} method".format(x)
# Out:
# 'recent method'

# %%
x = "latest"
f"{x[2:-1]} method"
# Out:
# 'tes method'

# %% [markdown]
# ## Convert one type into another

# %% [markdown]
# The type names can be used as "casting" functions, to convert values between types (i.e. create new objects)

# %%
type("1")
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
int("1")
# Out:
# 1

# %%
str(int("3"))
# Out:
# '3'

# %% [markdown]
# There is **no implicit casting** in the language. We do a comparisom with javascript to illustrate the different approach between to dynamically typed languages, but one is loosely typed (Javascript) and the other strongly typed (Python).

# %%
# %%javascript
# console.log(1=="1")
# console.log(1+"1")
# console.log(2*"2")

# %% [markdown]
# In Python, operators between different types do not perform explicit type casting

# %%
1 + "1"
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# <ipython-input-191-b780703cc5f9> in <module>()
# ----> 1 1 + "1"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# But, because everything is an object, operator overloading is supported in the language

# %%
r"\o/ "  * 3
# Out:
# '\\o/ \\o/ \\o/ '

# %% [markdown]
# ## Collections or Compound Data Structures
#
# There are 4 native compound types: List, Tuple, Dict and Set.

# %% [markdown]
# ### List (Mutable) and Tuple (Immutable)

# %%
my_list = [1, 2.0, 3+5j, "wild"]
my_list
# Out:
# [1, 2.0, (3+5j), 'wild']

# %%
type(my_list)
# Out:
# list

# %%
my_tuple = (1, 2.0, 3+5j, "wild")
my_tuple
# Out:
# (1, 2.0, (3+5j), 'wild')

# %%
type(my_tuple)
# Out:
# tuple

# %%
my_tuple == my_list
# Out:
# False

# %%
len(my_list), len(my_tuple), len('some string')
# Out:
# (4, 4, 11)

# %%
dir(my_tuple)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'count',
#  'index']

# %%
for i in my_list:
    print(type(i), i)
# Out:
# <class 'int'> 1
# <class 'float'> 2.0
# <class 'complex'> (3+5j)
# <class 'str'> wild

# %% [markdown]
# Tuples (immutable) and Lists (mutable) are both sequences (like strings), thus "sliceable"

# %%
my_tuple
# Out:
# (1, 2.0, (3+5j), 'wild')

# %%
my_tuple[1]
# Out:
# 2.0

# %%
my_tuple[1:-2]
# Out:
# (2.0,)

# %%
x = (8,)
type(x), x
# Out:
# (tuple, (8,))

# %% [markdown]
# Lists and Tuples can be easily combined

# %%
[1, 2, 3] + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
(1, 2, 3) + (4, 5, 6)
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# But only between themselves.

# %%
(1, 2, 3) + [1, 2, 3]
# Out:
# ------------------------------------------------------------
# TypeError                  Traceback (most recent call last)
# <ipython-input-229-fbe830b2579e> in <module>()
# ----> 1 (1, 2, 3) + [1, 2, 3]
#
# TypeError: can only concatenate tuple (not "list") to tuple

# %% [markdown]
# But we can easily transform one into the other

# %%
list((1, 2, 3)) + [4, 5, 6]
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
(1, 2, 3) + tuple([4, 5, 6])
# Out:
# (1, 2, 3, 4, 5, 6)

# %% [markdown]
# List can work as stacks (First-in, Last-out)

# %%
my_list = []

# %%
my_list.append(1)
my_list.append(2)
my_list.append(3)

# %%
my_list
# Out:
# [1, 2, 3]

# %%
my_list.pop()
# Out:
# 3

# %%
my_list
# Out:
# [1, 2]

# %%
len(my_list)
# Out:
# 2

# %% [markdown]
# List can work as queues (First-in, First-out)

# %%
my_queue = []

# %%
my_queue.insert(0, 1)
my_queue.insert(0, 2)
my_queue.insert(0, 3)

# %%
my_queue
# Out:
# [3, 2, 1]

# %%
my_queue.pop()
# Out:
# 1

# %%
my_queue
# Out:
# [3, 2]

# %% [markdown]
# You can also pop from the front

# %%
my_queue.pop(0)
# Out:
# 3

# %% [markdown]
# ### Sets

# %%
my_set = {4, 1, 2, 3, 3}
my_set
# Out:
# {1, 2, 3, 4}

# %%
type(my_set)
# Out:
# set

# %%
my_set_a  = set()
my_set_b = {1, 2, 3}

# %%
my_set_a.add(1)
my_set_a.add(5)

# %%
1 in my_set_a, 5 in my_set_b

# %%
{1, 2, 3}.union({3, 4, 5})

# %%
{1, 2, 3}.intersection({3, 4, 5})

# %%
my_set_a.difference(my_set_b)

# %% [markdown]
# ### Dictionaries

# %%
my_dict = {"one": 1, "two": 2}
my_dict
# Out:
# {'one': 1, 'two': 2}

# %%
type(my_dict)
# Out:
# dict

# %%
my_dict.get("two")
# Out:
# 2

# %%
"one" in my_dict
# Out:
# True

# %%
1 in my_dict
# Out:
# False

# %%
my_dict.keys()
# Out:
# dict_keys(['one', 'two'])

# %%
my_dict.values()
# Out:
# dict_values([1, 2])

# %%
my_dict.items()
# Out:
# dict_items([('one', 1), ('two', 2)])

# %%
dict(one=1, two=2)
# Out:
# {'one': 1, 'two': 2}

# %%
new_dict = dict(my_dict.items())
new_dict

# %%
new_dict == my_dict

# %%
new_dict is my_dict

# %%
id(new_dict),  id(my_dict)

# %%
len(new_dict)

# %%
del new_dict['one']

# %% [markdown]
# # Exception Handling

# %%
raise Exception("Some random exception")

# %%
try:
    raise ValueError('This is another artificial exxample')
except ValueError as ex:
    print(ex)

# %%
try:
    pass
except ValueError as ex:
    print(ex)
else:
    print("No exception was raised")

# %%
try:
    1/0
finally:
    print("Happens in spite of exceptions")

# %% [markdown]
# # Exercises
# Using the slice operator, invert the elements of the list below, then remove the first and the last elements.

# %%
[1, 2, 3, 4, 5]

# %% [markdown]
# Execute the cell below, then:
# 1. remove all the duplicates in the list refered by __sequence__
# 2. sort the results in descending order
# 3. store the results in a variable __result__ as a list

# %%
import random
sequence = []
for i in range(20):
    sequence.append(random.choice(range(100)))

# %%
sequence
